# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-mahandargi/R-programing/blob/main/Chi%20Square%20Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Contingency table data: counts for each satisfaction level per device type
data = {
    'Smart Thermostat': [120, 80, 50],  # Satisfied, Neutral, Dissatisfied
    'Smart Light': [150, 70, 30]     # Satisfied, Neutral, Dissatisfied
}

# Create DataFrame
df = pd.DataFrame(data)

# Assign index labels
df.index = ['Satisfied', 'Neutral', 'Dissatisfied']

# Print the DataFrame
display(df)
# Out:
#               Smart Thermostat  Smart Light
# Satisfied                  120          150
# Neutral                     80           70
# Dissatisfied                50           30

# %%
# State the null and alternative hypotheses
null_hypothesis = "H0: There is no association between device type (Smart Thermostat, Smart Light) and customer satisfaction level."
alternative_hypothesis = "H1: There is a significant association between device type (Smart Thermostat, Smart Light) and customer satisfaction level."

print("Null Hypothesis (H0):", null_hypothesis)
print("Alternative Hypothesis (H1):", alternative_hypothesis)
# Out:
# Null Hypothesis (H0): H0: There is no association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.
# Alternative Hypothesis (H1): H1: There is a significant association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.

# %%
from scipy.stats import chi2_contingency

# Perform the Chi-Square test
chi2_statistic, p_value, dof, expected_frequencies = chi2_contingency(df)

# Store the Chi-Square statistic
print(f"Chi-Square Statistic: {chi2_statistic}")
# Out:
# Chi-Square Statistic: 9.0

# %%
from scipy.stats import chi2

# Determine the critical value at a 0.05 significance level
critical_value = chi2.ppf(0.95, dof) # Use 1 - alpha for ppf for the right tail

# Print the critical value
print(f"Critical Value (alpha=0.05, dof={dof}): {critical_value}")
# Out:
# Critical Value (alpha=0.05, dof=2): 5.991464547107979

# %%
# Compare the chi2_statistic with the critical_value
if chi2_statistic > critical_value:
    decision = "Reject the null hypothesis (H0)."
    interpretation = "There is a significant association between device type and customer satisfaction level."
else:
    decision = "Fail to reject the null hypothesis (H0)."
    interpretation = "There is not enough evidence to suggest a significant association between device type and customer satisfaction level."

# Print the decision and interpretation
print(f"Chi-Square Statistic: {chi2_statistic}")
print(f"Critical Value: {critical_value}")
print(f"Decision: {decision}")
print(f"Interpretation: {interpretation}")
# Out:
# Chi-Square Statistic: 9.0
# Critical Value: 5.991464547107979
# Decision: Reject the null hypothesis (H0).
# Interpretation: There is a significant association between device type and customer satisfaction level.

# %%
report = f"""
Chi-Square Test for Independence Report

Hypotheses:
Null Hypothesis (H0): There is no association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.
Alternative Hypothesis (H1): There is a significant association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.

Analysis Results:
Chi-Square Statistic: {chi2_statistic:.4f}
Critical Value (alpha=0.05, dof={dof}): {critical_value:.4f}
P-value: {p_value:.4f}

Decision:
Based on the comparison of the Chi-Square statistic ({chi2_statistic:.4f}) and the critical value ({critical_value:.4f}), where the statistic is greater than the critical value, we reject the null hypothesis (H0).

Conclusion:
There is sufficient evidence at the 0.05 significance level to conclude that there is a significant association between the type of smart device (Smart Thermostat or Smart Light) and customer satisfaction level. The observed differences in satisfaction levels across the two device types are statistically significant and are unlikely to be due to random chance.
"""

print(report)
# Out:
# Chi-Square Test for Independence Report
#
# Hypotheses:
# Null Hypothesis (H0): There is no association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.
# Alternative Hypothesis (H1): There is a significant association between device type (Smart Thermostat, Smart Light) and customer satisfaction level.
#
# Analysis Results:
# Chi-Square Statistic: 9.0000
# Critical Value (alpha=0.05, dof=2): 5.9915
# P-value: 0.0111
#
# Decision:
# Based on the comparison of the Chi-Square statistic (9.0000) and the critical value (5.9915), where the statistic is greater than the critical value, we reject the null hypothesis (H0).
#
# Conclusion:
# ...
